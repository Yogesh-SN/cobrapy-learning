# %%
# !git clone https://github.com/Yogesh-SN/cobrapy-learning.git
# %cd cobrapy-learning/

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.insert(0, os.path.join(os.getcwd(), "src"))

# %%
from helpers import load_model
model = load_model('models/e_coli_core.xml')

# %%
model
# Out:
# <Model e_coli_core at 0x7997ef06e7e0>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_Ecoli_core_w_GAM = 0.8739215069684295</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>glc__D_e</td>
#       <td>EX_glc__D_e</td>
#       <td>10</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>nh4_e</td>
#       <td>EX_nh4_e</td>
#       <td>4.765</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>o2_e</td>
#       <td>EX_o2_e</td>
#       <td>21.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>pi_e</td>
#       <td>EX_pi_e</td>
#       <td>3.215</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
# ...

# %%
model.objective.expression
# Out:
# 1.0*BIOMASS_Ecoli_core_w_GAM - 1.0*BIOMASS_Ecoli_core_w_GAM_reverse_712e5

# %%
model.optimize()
# Out:
# <Solution 0.874 at 0x79980b6fe0f0>

# %% [markdown]
# #Growth Rate (μ) = Flux biomass
#
#
# ## [if normalized to 1 gDW]

# %%
from helpers import biomass_reaction

biomass = biomass_reaction(model)
print(biomass)
# Out:
# BIOMASS_Ecoli_core_w_GAM: 1.496 3pg_c + 3.7478 accoa_c + 59.81 atp_c + 0.361 e4p_c + 0.0709 f6p_c + 0.129 g3p_c + 0.205 g6p_c + 0.2557 gln__L_c + 4.9414 glu__L_c + 59.81 h2o_c + 3.547 nad_c + 13.0279 nadph_c + 1.7867 oaa_c + 0.5191 pep_c + 2.8328 pyr_c + 0.8977 r5p_c --> 59.81 adp_c + 4.1182 akg_c + 3.7478 coa_c + 59.81 h_c + 3.547 nadh_c + 13.0279 nadp_c + 59.81 pi_c

# %%
print(hasattr(helpers, "biomass_reaction"))
# Out:
# True
